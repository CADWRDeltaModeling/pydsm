# %%
import pandas as pd

# %% [markdown]
# Timedelta is a fixed amount while DateOffset is a relative amount based on time
# See the lines below, Timedelta adds 30 days to the date while DateOffset adds a month

# %%
tm=pd.Timestamp('31JAN1990')
display(tm+pd.Timedelta(1,'M'))
# Out:
# //anaconda3/envs/dsm2/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: M and Y units are deprecated and will be removed in a future version.
# Timestamp('1990-03-02 10:29:06')

# %%
tm+pd.DateOffset(months=1)
# Out:
# Timestamp('1990-02-28 00:00:00')
