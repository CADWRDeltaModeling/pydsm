# %% [markdown]
# # Reading hydro hdf5 files from DSM2
#
# This notebook is an example of using pydsm to read DSM2 h5 output.
#
# The timeseries are loaded as pandas DataFrame with datetime index and mcolumns of variable type (e.g. flow, stage, ec). This is similar to pyhecdss read in objects.
#
# In addition to the state of the model as time series, the HDF file also contains the input tables as intepreted by DSM2. I say interpreted because it also has important tables such as virtual cross-sections that is the geometry finally used by DSM2 even though the user specifies the physical geometry in the input files.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import h5py
import pydsm.io
#%conda install matplotlib
# Turn on ones below if in debug or development mode
#%load_ext autoreload
#%autoreload 2

# %% [markdown]
# ## Opening a H5 file
# This provides the handle to the HDF5 file.

# %%
filename='../../tests/historical_v82.h5'
h5f=h5py.File(filename,'r')

# %% [markdown]
# ## Reading H5 file with
#
# A HDF5 file consists of Groups and Datasets.
# Groups are like dicts with keys and values and Datasets are like arrays with some slicing abilities.
#
# A HDF5 file has a concept of path, similar to the file path.
# For example, the top level of the hydro h5 (HDF) file has 'hydro' as the top most Group

# %%
print('Topmost group of hydro h5 file: \n',list(h5f.keys()))
# Out:
# Topmost group of hydro h5 file:
#  ['hydro']

# %%
print('Children of hydro group:\n',list(h5f.get('hydro').keys()))
print('DSM2 Input Tables are children of input:\n',list(h5f.get('hydro').get('input').keys()))
print('DSM2 geometry are children of geometry: \n', list(h5f.get('hydro').get('geometry').keys()))
print('DSM2 time series output of state are children of data: \n', list(h5f.get('hydro').get('data').keys()))
# Out:
# Children of hydro group:
#  ['data', 'geometry', 'input']
# DSM2 Input Tables are children of input:
#  ['boundary_flow', 'boundary_stage', 'channel', 'channel_ic', 'envvar', 'gate', 'gate_pipe_device', 'gate_weir_device', 'input_gate', 'input_transfer_flow', 'io_file', 'layers', 'operating_rule', 'oprule_expression', 'oprule_time_series', 'output_channel', 'output_gate', 'output_reservoir', 'reservoir', 'reservoir_connection', 'reservoir_ic', 'reservoir_vol', 'scalar', 'source_flow', 'source_flow_reservoir', 'transfer', 'xsect', 'xsect_layer']
# DSM2 geometry are children of geometry:
#  ['channel_bottom', 'channel_location', 'channel_number', 'external_flow_names', 'hydro_comp_point', 'node_flow_connections', 'qext', 'reservoir_flow_connections', 'reservoir_names', 'reservoir_node_connect', 'stage_boundaries', 'transfer_names']
# DSM2 time series output of state are children of data:
#  ['channel area', 'channel avg area', 'channel flow', 'channel stage', 'qext flow', 'reservoir flow', 'reservoir height', 'transfer flow']

# %%
bf=h5f.get('hydro').get('input').get('boundary_flow')
pd.DataFrame(bf[:])
# Out:
#            name  node  sign   fillin                              file  \
# 0  b'calaveras'    21     1  b'last'  b'../../timeseries/hist0717.dss'
# 1   b'cosumnes'   446     1  b'last'  b'../../timeseries/hist0717.dss'
# 2       b'moke'   447     1  b'last'  b'../../timeseries/hist0717.dss'
# 3  b'north_bay'   273    -1  b'last'  b'../../timeseries/hist0717.dss'
# 4        b'sac'   330     1  b'last'  b'../../timeseries/hist0717.dss'
# 5   b'vernalis'    17     1  b'last'  b'../../timeseries/hist0717.dss'
# 6       b'yolo'   316     1  b'last'  b'../../timeseries/hist0717.dss'
#
#                                                 path
# 0   b'/FILL+CHAN/RCAL009/FLOW//1DAY/DWR-DMS-201707/'
# 1   b'/FILL+CHAN/RCSM075/FLOW//1DAY/DWR-DMS-201707/'
# 2   b'/FILL+CHAN/RMKL070/FLOW//1DAY/DWR-DMS-201707/'
# 3  b'/FILL+CHAN/SLBAR002/FLOW-EXPORT//1DAY/DWR-DM...
# 4   b'/FILL+CHAN/RSAC155/FLOW//1DAY/DWR-DMS-201707/'
# 5   b'/FILL+CHAN/RSAN112/FLOW//1DAY/DWR-DMS-201707/'
# 6  b'/FILL+CHAN/BYOLO040/FLOW//1DAY/DWR-DMS-201707/'

# %%
input_tables=pydsm.io.list_groups_as_df(filename, '/hydro/input')
for table in input_tables[0]:
    path='/hydro/input/'+str(table)
    print(path)
    display(pydsm.io.read_table_as_df(filename, path))
# Out:
# /hydro/input/boundary_flow
#         name node sign fillin                           file  \
# 0  calaveras   21    1   last  ../../timeseries/hist0717.dss
# 1   cosumnes  446    1   last  ../../timeseries/hist0717.dss
# 2       moke  447    1   last  ../../timeseries/hist0717.dss
# 3  north_bay  273   -1   last  ../../timeseries/hist0717.dss
# 4        sac  330    1   last  ../../timeseries/hist0717.dss
# 5   vernalis   17    1   last  ../../timeseries/hist0717.dss
# 6       yolo  316    1   last  ../../timeseries/hist0717.dss
#
#                                                 path
# 0      /FILL+CHAN/RCAL009/FLOW//1DAY/DWR-DMS-201707/
# 1      /FILL+CHAN/RCSM075/FLOW//1DAY/DWR-DMS-201707/
# 2      /FILL+CHAN/RMKL070/FLOW//1DAY/DWR-DMS-201707/
# 3  /FILL+CHAN/SLBAR002/FLOW-EXPORT//1DAY/DWR-DMS-...
# 4      /FILL+CHAN/RSAC155/FLOW//1DAY/DWR-DMS-201707/
# 5      /FILL+CHAN/RSAN112/FLOW//1DAY/DWR-DMS-201707/
# 6     /FILL+CHAN/BYOLO040/FLOW//1DAY/DWR-DMS-201707/
# /hydro/input/boundary_stage
#   name node  fillin                           file  \
# 0  mtz  361  linear  ../../timeseries/hist0717.dss
#
#                                                 path
# 0  /FILL+CHAN/RSAC054/STAGE//15MIN/DWR-DMS-201707...
# /hydro/input/channel
#     chan_no length manning dispersion upnode downnode
# 0         1  19500   0.035      360.0      1        2
# 1         2  14000   0.028      360.0      2        3
# 2         3  13000   0.028      360.0      3        4
# 3         4  14050   0.028      360.0      4        5
# 4         5  12350   0.028      360.0      5        6
# ..      ...    ...     ...        ...    ...      ...
# 516     575  13000   0.022     1800.0    328      357
# 517     700  10000   0.033      360.0    700      330
# 518     701  10000   0.033      360.0    701      700
# 519     702  10000   0.033      360.0    702      701
# 520     703  10000   0.033      360.0    703      702
#
# [521 rows x 6 columns]
# /hydro/input/channel_ic
#      chan_no distance stage    flow
# 0          1        0  10.0  2600.0
# 1          1   length   9.5  2400.0
# 2          2        0   9.5  2400.0
# 3          2   length   9.0  2200.0
# 4          3        0   8.5  2200.0
# ...      ...      ...   ...     ...
# 1037     701   length   5.0     0.0
# 1038     702        0   5.0     0.0
# 1039     702   length   5.0     0.0
# 1040     703        0   5.0     0.0
# 1041     703   length   5.0     0.0
#
# [1042 rows x 4 columns]
# /hydro/input/envvar
#                   name                                       value
# 0           BNDRYINPUT               ../../timeseries/hist0717.dss
# 1              CLIMATE         ../../timeseries/climate-5years.dss
# 2             DICUFILE            ../../timeseries/DCD_Sep2016.dss
# 3         DICUFILE-ECS              ../../timeseries/dicu_2017.dss
# 4         DICUFILE_ECE  ../../timeseries/dicuwq_3vals_extended.dss
# 5         DICUFILE_ECS  ../../timeseries/dicuwq_3vals_extended.dss
# 6           DSM2AGENCY                                         dwr
# 7         DSM2INPUTDIR                          ../../common_input
# 8         DSM2MODIFIER                              historical_v82
# 9        DSM2OUTPUTDIR                                    ./output
# 10            END_DATE                                   31Jan1990
# 11            END_TIME                                        0000
# 12         EVENTSINPUT                 ../../timeseries/events.dss
# 13            FINE_OUT                                       15MIN
# 14        FINE_OUT_DAY                                        1DAY
# 15         FLOWPATTERN                    ./output/FLOWPATTERN.dss
# 16            GATEFILE        ../../timeseries/gates-v8-201707.dss
# 17      GATEOUTPUTFILE                 ./output/historical_v82.dss
# 18     HISTFLOWVERSION                              DWR-DMS-201707
# 19     HISTQUALVERSION                              DWR-DMS-201707
# 20    HISTSTAGEVERSION                              DWR-DMS-201707
# 21     HYDROOUTDSSFILE                 ./output/historical_v82.dss
# 22        HYDROOUTFILE                 ./output/historical_v82.hof
# 23        HYDRORSTFILE                 ./output/historical_v82.hrf
# 24       HYDROTIDEFILE                  ./output/historical_v82.h5
# 25          OUTPUTFILE                          historical_v82.dss
# 26          PTMOUTFILE                 ./output/historical_v82.pof
# 27       PTMOUTPUTFILE                         ./output/ptmout.dss
# 28      PTM_START_DATE                                   01Jul2016
# 29          QUALBNDINP               ../../timeseries/hist0717.dss
# 30      QUALOUTDSSFILE                 ./output/historical_v82.dss
# 31         QUALOUTFILE                 ./output/historical_v82.qof
# 32         QUALRSTFILE                 ./output/historical_v82.qrf
# 33        QUALTIDEFILE               ./output/historical_v82_ec.h5
# 34     QUAL_START_DATE                                   03Jan1990
# 35          START_DATE                                   01Jan1990
# 36          START_TIME                                        2400
# 37   STOCKTON_EFF_FLOW                                         0.0
# 38  STOCKTON_FLOW_FILE                                    constant
# 39            STUDYDIR                                           .
# 40             TEMPDIR                                     z:/temp
# 41          TSINPUTDIR                            ../../timeseries
# 42         VERSIONDATE                                      201707
# 43      WWTP_FLOW_FILE          ../../timeseries/WWTP1992_2015.dss
# /hydro/input/gate
#                            name   from_obj from_identifier to_node
# 0                 7_mile@3_mile    channel             308     240
# 1                    7_mile@sjr    channel             307      41
# 2                  FalseBarrier    channel             279      44
# 3                 clifton_court  reservoir   clifton_court      72
# 4           delta_cross_channel    channel             365     342
# 5                   goodyear_sl    channel             473     367
# 6            grant_line_barrier    channel             206     172
# 7              middle_r_barrier    channel             134     112
# 8    montezuma_salinity_control    channel             512     418
# 9         morrow_c_line_outfall    channel             542     365
# 10        morrow_m_line_outfall    channel             539     378
# 11            morrow_sys_intake    channel             537     384
# 12           old_r@head_barrier    channel              54       8
# 13          old_r@tracy_barrier    channel              79      69
# 14            paradise_cut_weir    channel             195       5
# 15  roaring_river_slough_intake    channel             529     418
# 16                 sandmound_sl    channel             261     205
# 17                 tom_paine_sl    channel             194     149
# /hydro/input/gate_pipe_device
#                       gate_name device nduplicate radius    elev cf_from_node  \
# 0                 7_mile@3_mile  pipes          2    2.0  -4.595          0.5
# 1                    7_mile@sjr  pipes          1    2.0  -4.628          0.0
# 2                   goodyear_sl  pipes          4    2.0  -0.408          0.4
# 3            grant_line_barrier  pipes          6    2.0  -4.187          0.6
# 4              middle_r_barrier  pipes          6    2.0  -1.733          0.6
# 5         morrow_c_line_outfall  pipes          2    1.5   0.059          0.5
# 6         morrow_m_line_outfall  pipes          3    2.0  -2.321          0.5
# 7             morrow_sys_intake  pipes          3    2.0  -2.598          0.2
# 8            old_r@head_barrier  pipes          8    2.0  -5.674          0.6
# 9           old_r@tracy_barrier  pipes          9    2.0  -3.641          0.6
# 10  roaring_river_slough_intake  pipes          8    2.5   -2.51          0.5
# 11                 sandmound_sl  pipes          2   2.75  -0.661          0.5
# 12                 tom_paine_sl  pipes          6   1.88  -1.161          0.6
#
#    cf_to_node        default_op
# 0         0.5         gate_open
# 1         0.0        gate_close
# 2         0.4    unidir_to_node
# 3         0.6  unidir_from_node
# 4         0.6    unidir_to_node
# 5         0.5    unidir_to_node
# 6         0.5    unidir_to_node
# 7         0.2  unidir_from_node
# 8         0.6         gate_open
# 9         0.6  unidir_from_node
# 10        0.5  unidir_from_node
# 11        0.5  unidir_from_node
# 12        0.6  unidir_from_node
# /hydro/input/gate_weir_device
#                      gate_name               device nduplicate  width  \
# 0                 FalseBarrier              barrier          1  950.0
# 1                clifton_court      reservoir_gates          5   20.0
# 2          delta_cross_channel  cross_channel_gates          2   60.0
# 3           grant_line_barrier              barrier          1  180.0
# 4             middle_r_barrier              barrier          1  140.0
# 5   montezuma_salinity_control            boat_lock          1   20.0
# 6   montezuma_salinity_control          flashboards          1   66.0
# 7   montezuma_salinity_control  modified_flashboard          1   40.0
# 8   montezuma_salinity_control         radial_gates          3   36.0
# 9           old_r@head_barrier         fall_barrier          1   32.0
# 10          old_r@head_barrier         fish_barrier          1  167.0
# 11         old_r@tracy_barrier              barrier          1   75.0
# 12           paradise_cut_weir                 weir          1  237.0
#
#        elev  height cf_from_node cf_to_node        default_op
# 0      20.0  9999.0         0.65       0.65         gate_open
# 1    -7.748  9999.0          1.0        1.0  unidir_from_node
# 2   -11.218  9999.0          2.0        2.0         gate_open
# 3     3.313  9999.0          0.8        0.8         gate_open
# 4     3.267  9999.0          0.7        0.7         gate_open
# 5     -7.51  9999.0          0.8        0.8        gate_close
# 6    -17.01  9999.0          1.0        1.0        gate_close
# 7     -8.51     1.0          0.6        0.6        gate_close
# 8    -22.51  9999.0          1.0        1.0         gate_open
# 9     2.326  9999.0          0.7        0.7         gate_open
# 10   12.326  9999.0          0.7        0.7         gate_open
# 11    4.359  9999.0          0.8        0.8         gate_open
# 12   14.856  9999.0         0.77       0.77         gate_open
# /hydro/input/input_gate
# Empty DataFrame
# Columns: [gate_name, device, variable, fillin, file, path]
# Index: []
# /hydro/input/input_transfer_flow
# Empty DataFrame
# Columns: [transfer_name, fillin, file, path]
# Index: []
# /hydro/input/io_file
#    model     type   io interval                                    file
# 0  hydro     echo  out     none  ./output/hydro_echo_historical_v82.inp
# 1  hydro     hdf5  out    30min              ./output/historical_v82.h5
# 2  hydro   output  out     none             ./output/historical_v82.hof
# 3  hydro  restart  out     1mon             ./output/historical_v82.hrf
# /hydro/input/layers
#    number                                               name
# 0       0                               historical_hydro.inp
# 1       1                       configuration_historical.inp
# 2       2  ../../common_input/channel_std_delta_grid_navd...
# 3       3  ../../common_input/reservoir_std_delta_grid_na...
# 4       4  ../../common_input/gate_std_delta_grid_2016050...
# 5       5  ../../common_input/channel_ic_std_delta_grid_n...
# 6       6  ../../common_input/reservoir_ic_std_delta_grid...
# 7       7  ../../common_input/boundary_flow_delta_histori...
# 8       8  ../../common_input/source_flow_delta_historica...
# 9       9  ../../common_input/boundary_stage_delta_histor...
# 10     10  ../../common_input/source_flow_dcd_historical_...
# 11     11  ../../common_input/source_flow_jones_hydro_200...
# 12     12  ../../common_input/oprule_historical_gate_2011...
# 13     13  ../../common_input/oprule_hist_temp_barriers_2...
# 14     14  ../../common_input/output_channel_std_hydro_rk...
# 15     15  ../../common_input/output_channel_hydro_v81_ca...
# 16     16  ../../common_input/output_channel_hydro_v81_12...
# 17     17  ../../common_input/output_reservoir_std_hydro_...
# 18     18  ../../common_input/output_channel_std_hydro_bo...
# /hydro/input/operating_rule
#                          name  \
# 0             FalseBarrier_in
# 1            FalseBarrier_out
# 2               clfct_gate_op
# 3                 dcc_gate_op
# 4            glc_barrier_elev
# 5           glc_barrier_width
# 6              glc_install_in
# 7             glc_install_out
# 8            glc_pipe_op_down
# 9            mid_barrier_elev
# 10   mid_r_barrier_install_in
# 11  mid_r_barrier_install_out
# 12         mid_r_pipe_op_down
# 13       morrow_c_change_ndup
# 14           mscs_boatlock_op
# 15        mscs_boatlock_op_to
# 16                 mscs_close
# 17              mscs_close_to
# 18         mscs_flashboard_op
# 19      mscs_flashboard_op_to
# 20         mscs_modifiedFB_op
# 21      mscs_modifiedFB_op_to
# 22                  mscs_open
# 23               mscs_open_to
# 24   old_r_barrier_chg_2000_1
# 25   old_r_barrier_chg_2000_2
# 26   old_r_barrier_install_in
# 27  old_r_barrier_install_out
# 28              old_r_pipe_op
# 29      orhrb_fall_install_in
# 30     orhrb_fall_install_out
# 31          orhrb_fallweir_op
# 32       orhrb_fallweir_op_to
# 33      orhrb_fish_install_in
# 34     orhrb_fish_install_out
# 35              orhrb_pipe_op
# 36           orhrb_pipe_op_to
# 37       orhrb_pipes_chg_elev
# 38              orhrb_weir_op
# 39           orhrb_weir_op_to
# 40            sandmound_close
# 41             sandmound_open
#
#                                                action  \
# 0          SET gate_install(gate=FalseBarrier) TO 1.0
# 1          SET gate_install(gate=FalseBarrier) TO 0.0
# 2   SET gate_op(gate=clifton_court,device=reservoi...
# 3   SET gate_op(gate=delta_cross_channel,device=cr...
# 4   SET gate_elev(gate=grant_line_barrier, device=...
# 5   SET gate_width(gate=grant_line_barrier, device...
# 6    SET gate_install(gate=grant_line_barrier) TO 1.0
# 7    SET gate_install(gate=grant_line_barrier) TO 0.0
# 8   SET gate_op(gate=grant_line_barrier,device=pip...
# 9   SET gate_elev(gate=middle_r_barrier, device=ba...
# 10     SET gate_install(gate=middle_r_barrier) TO 1.0
# 11     SET gate_install(gate=middle_r_barrier) TO 0.0
# 12  SET gate_op(gate=middle_r_barrier,device=pipes...
# 13  SET gate_nduplicate(gate=morrow_c_line_outfall...
# 14  SET gate_op(gate=montezuma_salinity_control,de...
# 15  SET gate_op(gate=montezuma_salinity_control,de...
# 16  SET gate_op(gate=montezuma_salinity_control,de...
# 17  SET gate_op(gate=montezuma_salinity_control,de...
# 18  SET gate_op(gate=montezuma_salinity_control,de...
# 19  SET gate_op(gate=montezuma_salinity_control,de...
# 20  SET gate_op(gate=montezuma_salinity_control,de...
# 21  SET gate_op(gate=montezuma_salinity_control,de...
# 22  SET gate_op(gate=montezuma_salinity_control,de...
# 23  SET gate_op(gate=montezuma_salinity_control,de...
# 24  SET gate_width(gate=old_r@tracy_barrier,device...
# 25  SET gate_width(gate=old_r@tracy_barrier,device...
# 26  SET gate_install(gate=old_r@tracy_barrier) TO 1.0
# 27  SET gate_install(gate=old_r@tracy_barrier) TO 0.0
# 28  SET gate_op(gate=old_r@tracy_barrier,device=pi...
# 29   SET gate_install(gate=old_r@head_barrier) TO 1.0
# 30   SET gate_install(gate=old_r@head_barrier) TO 0.0
# 31  SET gate_op(gate=old_r@head_barrier,device=fal...
# 32  SET gate_op(gate=old_r@head_barrier,device=fal...
# 33   SET gate_install(gate=old_r@head_barrier) TO 1.0
# 34   SET gate_install(gate=old_r@head_barrier) TO 0.0
# 35  SET gate_op(gate=old_r@head_barrier,device=pip...
# 36  SET gate_op(gate=old_r@head_barrier,device=pip...
# 37  SET gate_elev(gate=old_r@head_barrier,device=p...
# 38  SET gate_op(gate=old_r@head_barrier,device=fis...
# 39  SET gate_op(gate=old_r@head_barrier,device=fis...
# 40  SET gate_op(gate=sandmound_sl,device=pipes,dir...
# 41  SET gate_op(gate=sandmound_sl,device=pipes,dir...
#
#                                               trigger
# 0     DATETIME >= 28MAY2015 AND DATETIME <= 01OCT2015
# 1        DATETIME < 28MAY2015 OR DATETIME > 01OCT2015
# 2                                                TRUE
# 3                                                TRUE
# 4                                                TRUE
# 5                                                TRUE
# 6                         ts(name=glc_install) >= 1.0
# 7                         ts(name=glc_install) <= 0.0
# 8                                                TRUE
# 9                                                TRUE
# 10                       ts(name=midr_install) >= 1.0
# 11                       ts(name=midr_install) <= 0.0
# 12                                               TRUE
# 13                        DATETIME >= 28SEP1992 00:00
# 14                                               TRUE
# 15                                               TRUE
# 16  (mscs_velclose AND mscs_calc) OR ts(name=mscs_...
# 17  (mscs_velclose AND mscs_calc) OR ts(name=mscs_...
# 18                                               TRUE
# 19                                               TRUE
# 20                                               TRUE
# 21                                               TRUE
# 22  (mscs_dhopen AND mscs_calc) OR ts(name=mscs_op...
# 23  (mscs_dhopen AND mscs_calc) OR ts(name=mscs_op...
# 24                        DATETIME >= 31MAY2000 00:00
# 25                        DATETIME >= 01JUN2000 00:00
# 26                       ts(name=oldr_install) >= 1.0
# 27                       ts(name=oldr_install) <= 0.0
# 28                                               TRUE
# 29                  ts(name=orhrb_weirop_fall) >= 1.0
# 30                  ts(name=orhrb_weirop_fall) <= 0.0
# 31                                               TRUE
# 32                                               TRUE
# 33                ts(name=orhrb_weirop_spring) >= 1.0
# 34                ts(name=orhrb_weirop_spring) <= 0.0
# 35                                               TRUE
# 36                                               TRUE
# 37                                               TRUE
# 38                                               TRUE
# 39                                               TRUE
# 40                        DATETIME >= 07APR1989 00:00
# 41                        DATETIME >= 10APR1989 00:00
# /hydro/input/oprule_expression
#             name                                         definition
# 0      mscs_calc                               ts(name=mscs_op) < 0
# 1    mscs_dhopen  (chan_stage(channel=512,dist=6038) - chan_stag...
# 2  mscs_velclose                chan_vel(channel=513,dist=0) < -0.1
# /hydro/input/oprule_time_series
#                    name fillin                                  file  \
# 0              clfct_op   last  ../../timeseries/gates-v8-201707.dss
# 1                dcc_op   last  ../../timeseries/gates-v8-201707.dss
# 2              glc_elev   last  ../../timeseries/gates-v8-201707.dss
# 3           glc_install   last  ../../timeseries/gates-v8-201707.dss
# 4        glc_pipeopdown   last  ../../timeseries/gates-v8-201707.dss
# 5             glc_width   last  ../../timeseries/gates-v8-201707.dss
# 6              mid_elev   last  ../../timeseries/gates-v8-201707.dss
# 7          midr_install   last  ../../timeseries/gates-v8-201707.dss
# 8       midr_pipeopdown   last  ../../timeseries/gates-v8-201707.dss
# 9            mscs_fract   last  ../../timeseries/gates-v8-201707.dss
# 10              mscs_op   last  ../../timeseries/gates-v8-201707.dss
# 11    mtzsl_boatlock_op   last  ../../timeseries/gates-v8-201707.dss
# 12  mtzsl_flashboard_op   last  ../../timeseries/gates-v8-201707.dss
# 13       mtzsl_modfb_op   last  ../../timeseries/gates-v8-201707.dss
# 14         oldr_install   last  ../../timeseries/gates-v8-201707.dss
# 15          oldr_pipeop   last  ../../timeseries/gates-v8-201707.dss
# 16       orhrb_pipeelev   last  ../../timeseries/gates-v8-201707.dss
# 17         orhrb_pipeop   last  ../../timeseries/gates-v8-201707.dss
# 18    orhrb_weirop_fall   last  ../../timeseries/gates-v8-201707.dss
# 19  orhrb_weirop_spring   last  ../../timeseries/gates-v8-201707.dss
#
#                                                  path
# 0   /HIST+GATE/CHWST000/POS//IR-YEAR/DWR-OM-JOC-DSM2/
# 1       /HIST+GATE/RSAC128/POS//IR-YEAR/DWR-DMS-DSM2/
# 2   /HIST+GATE/GL_CN/WEIRELEVATION//IR-DECADE/DWR-...
# 3        /HIST+GATE/GL_CN/INSTALL//IR-DECADE/DWR-BDO/
# 4   /HIST+GATE/GL_CN/PIPE_OP_DOWN//IR-DECADE/DWR-BDO/
# 5      /HIST+GATE/GL_CN/WEIRWIDTH//IR-DECADE/DWR-BDO/
# 6   /HIST+GATE/MID_R/WEIRELEVATION//IR-DECADE/DWR-...
# 7        /HIST+GATE/MID_R/INSTALL//IR-DECADE/DWR-BDO/
# 8   /HIST+GATE/MID_R/PIPE_OP_DOWN//IR-DECADE/DWR-BDO/
# 9   /HIST+GATE/MTZSL/RADIAL_FRACT//IR-DECADE/DWR-ESO/
# 10     /HIST+GATE/MTZSL/RADIAL_OP//IR-DECADE/DWR-ESO/
# 11   /HIST+GATE/MTZSL/BOATLOCK_OP//IR-DECADE/DWR-ESO/
# 12  /HIST+GATE/MTZSL/FLASHBOARD_OP//IR-DECADE/DWR-...
# 13  /HIST+GATE/MTZSL/MOD_FLASHBOARD_OP//IR-DECADE/...
# 14       /HIST+GATE/OLD_R/INSTALL//IR-DECADE/DWR-BDO/
# 15  /HIST+GATE/OLD_R/PIPE_OP_DOWN//IR-DECADE/DWR-BDO/
# 16  /HIST+GATE/ORHRB/PIPEELEV//IR-DECADE/DWR-BDO_N...
# 17       /HIST+GATE/ORHRB/PIPE_OP//IR-DECADE/DWR-BDO/
# 18  /HIST+GATE/ORHRB_FALL/WEIR_OP//IR-DECADE/DWR-BDO/
# 19       /HIST+GATE/ORHRB/WEIR_OP//IR-DECADE/DWR-BDO/
# /hydro/input/output_channel
#          name chan_no distance variable interval period_op  \
# 0     CHAN134     134     3814     flow    15MIN      inst
# 1     CHAN134     134     3814    stage    15MIN      inst
# 2     CHAN212     212        0     flow    15MIN      inst
# 3     CHAN212     212        0    stage    15MIN      inst
# 4     CHAN392     392        0     flow    15MIN      inst
# ..        ...     ...      ...      ...      ...       ...
# 243       trn     172      990    stage    15MIN      inst
# 244  vernalis      17        0     flow    15MIN      inst
# 245  vernalis      17        0    stage    15MIN      inst
# 246      yolo     398        0     flow    15MIN      inst
# 247      yolo     398        0    stage    15MIN      inst
#
#                             file
# 0    ./output/historical_v82.dss
# 1    ./output/historical_v82.dss
# 2    ./output/historical_v82.dss
# 3    ./output/historical_v82.dss
# 4    ./output/historical_v82.dss
# ..                           ...
# 243  ./output/historical_v82.dss
# 244  ./output/historical_v82.dss
# 245  ./output/historical_v82.dss
# 246  ./output/historical_v82.dss
# 247  ./output/historical_v82.dss
#
# [248 rows x 7 columns]
# /hydro/input/output_gate
# Empty DataFrame
# Columns: [name, gate_name, device, variable, interval, period_op, file]
# Index: []
# /hydro/input/output_reservoir
#             name       res_name  node variable interval period_op  \
# 0  clifton_court  clifton_court    72     flow    15MIN      inst
# 1  clifton_court  clifton_court  none    stage    15MIN      inst
#
#                           file
# 0  ./output/historical_v82.dss
# 1  ./output/historical_v82.dss
# /hydro/input/reservoir
#             name      area bot_elev
# 0         bethel   15.5031   -5.741
# 1  clifton_court    91.868   -7.748
# 2  discovery_bay    19.632  -13.654
# 3   franks_tract  141.7864   -7.754
# 4        liberty   226.904   -7.652
# 5        mildred   42.2996  -11.823
# /hydro/input/reservoir_connection
#          res_name node coef_in coef_out
# 0          bethel  220  1500.0   1500.0
# 1   discovery_bay  197  1125.0      0.0
# 2   discovery_bay  198  1125.0   1125.0
# 3    franks_tract  103  2250.0   2250.0
# 4    franks_tract  216  1500.0   1500.0
# 5    franks_tract  219  1500.0   1500.0
# 6    franks_tract  224  2250.0   2250.0
# 7    franks_tract  225  1500.0   1500.0
# 8    franks_tract  232  2250.0   2250.0
# 9         liberty  322  7500.0   5625.0
# 10        mildred  127  1500.0   1500.0
# 11        mildred  129  1500.0   1500.0
# 12        mildred  130  1500.0   1500.0
# 13        mildred  136  1500.0   1500.0
# /hydro/input/reservoir_ic
#         res_name stage
# 0         bethel   5.0
# 1  clifton_court   5.0
# 2  discovery_bay   5.0
# 3   franks_tract   5.0
# 4        liberty   7.0
# 5        mildred   5.0
# /hydro/input/reservoir_vol
# Empty DataFrame
# Columns: [res_name, elev, area, volume]
# Index: []
# /hydro/input/scalar
#                name                             value
# 0     binary_output                             false
# 1         checkdata                             false
# 2          cont_bad                             false
# 3      cont_missing                              true
# 4     cont_question                              true
# 5    cont_unchecked                              true
# 6            deltax                              5000
# 7     display_intvl                              1day
# 8        dss_direct                              true
# 9      flush_output                             20day
# 10          gravity                              32.2
# 11  hydro_time_step                             15min
# 12      levee_slope                              0.33
# 13          maxiter                                20
# 14       printlevel                                 1
# 15     run_end_date                         31Jan1990
# 16   run_start_date                         01Jan1990
# 17   run_start_time                              2400
# 18         temp_dir                           c:/temp
# 19            theta                               0.6
# 20            title  Hydro simulation: historical_v82
# 21       toleranceq                             0.001
# 22       tolerancez                            0.0008
# 23     warn_missing                              true
# 24    warn_question                              true
# 25   warn_unchecked                             false
# /hydro/input/source_flow
#               name node sign fillin                              file  \
# 0              ccc  206   -1   last     ../../timeseries/hist0717.dss
# 1          cccoldr   80   -1   last     ../../timeseries/hist0717.dss
# 2              ccw  191   -1   last     ../../timeseries/hist0717.dss
# 3              cvp  181   -1   last     ../../timeseries/hist0717.dss
# 4       dicu_div_1    1   -1   last  ../../timeseries/DCD_Sep2016.dss
# ..             ...  ...  ...    ...                               ...
# 774   dicu_seep_98   98   -1   last  ../../timeseries/DCD_Sep2016.dss
# 775       jones_in  118   -1   last       ../../timeseries/events.dss
# 776      jones_out  118    1   last       ../../timeseries/events.dss
# 777  jones_pumpout  121    1   last       ../../timeseries/events.dss
# 778       stockton   15    1   last                          constant
#
#                                                   path
# 0    /FILL+CHAN/CHCCC006/FLOW-DIVERSION//1DAY/DWR-D...
# 1    /FILL+CHAN/ROLD034/FLOW-EXPORT//1DAY/DWR-DMS-2...
# 2    /FILL+CHAN/CHVCT001/FLOW-EXPORT//1DAY/DWR-DMS-...
# 3    /FILL+CHAN/CHDMC004/FLOW-EXPORT//1DAY/DWR-DMS-...
# 4            /DICU-HIST+NODE/1/DIV-FLOW//1DAY/DWR-BDO/
# ..                                                 ...
# 774        /DICU-HIST+NODE/98/SEEP-FLOW//1DAY/DWR-BDO/
# 775  /HIST+CHAN/JONES-IN/FLOW-DIVERSION//15MIN/DWR-...
# 776          /HIST+CHAN/JONES-OUT/FLOW//15MIN/DWR-DMS/
# 777      /HIST+CHAN/JONES-PUMPOUT/FLOW//15MIN/DWR-DMS/
# 778                                                0.0
#
# [779 rows x 6 columns]
# /hydro/input/source_flow_reservoir
#               name       res_name sign fillin  \
# 0    dicu_div_bbid  clifton_court   -1   last
# 1  dicu_drain_bbid  clifton_court    1   last
# 2   dicu_seep_bbid  clifton_court   -1   last
# 3              swp  clifton_court   -1   last
#
#                                file  \
# 0  ../../timeseries/DCD_Sep2016.dss
# 1  ../../timeseries/DCD_Sep2016.dss
# 2  ../../timeseries/DCD_Sep2016.dss
# 3     ../../timeseries/hist0717.dss
#
#                                                 path
# 0       /DICU-HIST+RSVR/BBID/DIV-FLOW//1DAY/DWR-BDO/
# 1     /DICU-HIST+RSVR/BBID/DRAIN-FLOW//1DAY/DWR-BDO/
# 2      /DICU-HIST+RSVR/BBID/SEEP-FLOW//1DAY/DWR-BDO/
# 3  /FILL+CHAN/CHSWP003/FLOW-EXPORT//1DAY/DWR-DMS-...
# /hydro/input/transfer
# Empty DataFrame
# Columns: [name, from_obj, from_identifier, to_obj, to_identifier]
# Index: []
# /hydro/input/xsect
# Empty DataFrame
# Columns: [chan_no, dist, file]
# Index: []
# /hydro/input/xsect_layer
#       chan_no   dist    elev     area  width wet_perim
# 0           1   0.24   4.225      0.0    0.0       0.0
# 1           1   0.24   5.995    103.6  116.4     116.5
# 2           1   0.24  27.715  10088.4  803.1     805.2
# 3           1   0.24  35.345  16724.9  936.8     939.9
# 4           1   0.24  38.475  19710.7  970.3     973.6
# ...       ...    ...     ...      ...    ...       ...
# 10888     703  0.875   30.72  19208.3  574.4     594.2
# 10889     703  0.875   30.92  19331.5  682.7     702.5
# 10890     703  0.875   35.03  22292.8  755.6     776.7
# 10891     703  0.875    41.9  27735.4  830.4     854.0
# 10892     703  0.875   42.09  27898.3  830.7     854.3
#
# [10893 rows x 6 columns]

# %%
print(h5f.get('/input'))
# Out:
# None

# %% [markdown]
# # Hydro data file structure
# DSM2 Hydro HDF5 stores data under three groups:
#  * /hydro/data
#  * /hydro/input
#  * /hydro/geometry
#
# The next cell prints out the tables available under each

# %%
group_paths=['/hydro/input','/hydro/data','/hydro/geometry']
for path in group_paths:
    print(path)
    for key in h5f.get(path).keys():
        print('    ',key)
# Out:
# /hydro/input
#      boundary_flow
#      boundary_stage
#      channel
#      channel_ic
#      envvar
#      gate
#      gate_pipe_device
#      gate_weir_device
#      input_gate
#      input_transfer_flow
#      io_file
#      layers
#      operating_rule
#      oprule_expression
#      oprule_time_series
#      output_channel
#      output_gate
#      output_reservoir
#      reservoir
#      reservoir_connection
#      reservoir_ic
#      reservoir_vol
#      scalar
#      source_flow
#      source_flow_reservoir
#      transfer
#      xsect
#      xsect_layer
# /hydro/data
#      channel area
#      channel avg area
#      channel flow
#      channel stage
#      qext flow
#      reservoir flow
#      reservoir height
#      transfer flow
# /hydro/geometry
#      channel_bottom
#      channel_location
#      channel_number
#      external_flow_names
#      hydro_comp_point
#      node_flow_connections
#      qext
#      reservoir_flow_connections
#      reservoir_names
#      reservoir_node_connect
#      stage_boundaries
#      transfer_names

# %% [markdown]
# ## Channel indices to numbers
# The data in DataSets under /hydro/data is typically indexed by time, channel index, upstream/downstream if needed
# The channel index can be mapped to the channel number by looking up that information from /hydro/geometry/channel_number

# %%
channel_numbers=pd.DataFrame(h5f.get('/hydro/geometry/channel_number')[:])
print(channel_numbers)
channel_index2number=channel_numbers[0].to_dict()
index=157
print('This channel number for index:',index, ' should be 169. It is ',channel_index2number[index])
channel_number2index= {value: key for key, value in channel_index2number.items()}
print('This channel index for number:', 169, ' should be ',index,'. It is ',channel_number2index[169])
# Out:
#        0
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 516  575
# 517  700
# 518  701
# 519  702
# 520  703
#
# [521 rows x 1 columns]
# This channel number for index: 157  should be 169. It is  169
# This channel index for number: 169  should be  157 . It is  157

# %%
channel_location=pd.DataFrame(h5f.get('/hydro/geometry/channel_location')[:],dtype=np.str)
display(channel_location)
# Out:
#             0
# 0    upstream
# 1  downstream

# %% [markdown]
# ## Extracting time series data
# Extracting data can then be done using the channel numbers. All data arrays have the first axis as time. The time start and time interval is available in the attrs along with other meta data.
#
# Flow data shape is *time* x *channel index* x *channel location*
#
# time start is available in attribue "START_TIME"
# channel index to channel numbers is explained above
# channel location (upstream/downstream) is available in /hydro/geometry/channel_location

# %%
channel_location[0].str.upper()
# Out:
# 0      UPSTREAM
# 1    DOWNSTREAM
# Name: 0, dtype: object

# %%
flowdata = h5f.get('/hydro/data/channel flow')
print(flowdata.shape)
#
interval_string=flowdata.attrs['interval'][0].decode('UTF-8')
model=flowdata.attrs['model'][0].decode('UTF-8')
model_version=flowdata.attrs['model_version'][0].decode('UTF-8')
start_time=pd.to_datetime(flowdata.attrs['start_time'][0].decode('UTF-8'))
print('Start time: ',start_time)
print('time interval: ',interval_string)
print('Model: ',model)
print('Model Version: ',model_version)
#
print('Slicing along time for channel number: 441')
channel_id=441
location='UPSTREAM'
channel_index= channel_number2index[channel_id]# channel_numbers[channel_numbers[0]==441] #-- slow way
location_index=channel_location[channel_location[0].str.upper()==location]
darr=flowdata[:,channel_index,location_index]
ts441=pd.DataFrame(darr,
                   columns=[str(channel_id)+'-'+location],
                   index=pd.date_range(start_time,freq='30T',periods=darr.shape[0]),dtype=np.float32)
# Out:
# (1393, 521, 2)
# Start time:  1990-01-02 00:00:00
# time interval:  30min
# Model:  Hydro
# Model Version:  8.2
# Slicing along time for channel number: 441

# %%
ts441['01jan1990':'10jan1990'].plot()

# %%
for key in flowdata.attrs.keys(): print (key, flowdata.attrs[key])
# Out:
# CLASS [b'TIMESERIES']
# DIMENSION_LABELS [b'channel_number' b'channel_number' b'time']
# DIMENSION_LIST [array([<HDF5 object reference>, <HDF5 object reference>], dtype=object)
#  array([], dtype=object) array([], dtype=object)]
# interval [b'30min']
# model [b'Hydro']
# model_version [b'8.2']
# start_time [b'1990-01-02 00:00:00']

# %%
import pydsm.io

# %%
#pd.DataFrame()
pd.DataFrame(h5f['/hydro/input/boundary_flow'][:],dtype=np.str)
# Out:
#         name node sign fillin                           file  \
# 0  calaveras   21    1   last  ../../timeseries/hist0717.dss
# 1   cosumnes  446    1   last  ../../timeseries/hist0717.dss
# 2       moke  447    1   last  ../../timeseries/hist0717.dss
# 3  north_bay  273   -1   last  ../../timeseries/hist0717.dss
# 4        sac  330    1   last  ../../timeseries/hist0717.dss
# 5   vernalis   17    1   last  ../../timeseries/hist0717.dss
# 6       yolo  316    1   last  ../../timeseries/hist0717.dss
#
#                                                 path
# 0      /FILL+CHAN/RCAL009/FLOW//1DAY/DWR-DMS-201707/
# 1      /FILL+CHAN/RCSM075/FLOW//1DAY/DWR-DMS-201707/
# 2      /FILL+CHAN/RMKL070/FLOW//1DAY/DWR-DMS-201707/
# 3  /FILL+CHAN/SLBAR002/FLOW-EXPORT//1DAY/DWR-DMS-...
# 4      /FILL+CHAN/RSAC155/FLOW//1DAY/DWR-DMS-201707/
# 5      /FILL+CHAN/RSAN112/FLOW//1DAY/DWR-DMS-201707/
# 6     /FILL+CHAN/BYOLO040/FLOW//1DAY/DWR-DMS-201707/

# %%
import pydsm.io
x=pydsm.io.read_table_as_df(filename,'/hydro/input/boundary_flow')
display(x)
# Out:
#         name node sign fillin                           file  \
# 0  calaveras   21    1   last  ../../timeseries/hist0717.dss
# 1   cosumnes  446    1   last  ../../timeseries/hist0717.dss
# 2       moke  447    1   last  ../../timeseries/hist0717.dss
# 3  north_bay  273   -1   last  ../../timeseries/hist0717.dss
# 4        sac  330    1   last  ../../timeseries/hist0717.dss
# 5   vernalis   17    1   last  ../../timeseries/hist0717.dss
# 6       yolo  316    1   last  ../../timeseries/hist0717.dss
#
#                                                 path
# 0      /FILL+CHAN/RCAL009/FLOW//1DAY/DWR-DMS-201707/
# 1      /FILL+CHAN/RCSM075/FLOW//1DAY/DWR-DMS-201707/
# 2      /FILL+CHAN/RMKL070/FLOW//1DAY/DWR-DMS-201707/
# 3  /FILL+CHAN/SLBAR002/FLOW-EXPORT//1DAY/DWR-DMS-...
# 4      /FILL+CHAN/RSAC155/FLOW//1DAY/DWR-DMS-201707/
# 5      /FILL+CHAN/RSAN112/FLOW//1DAY/DWR-DMS-201707/
# 6     /FILL+CHAN/BYOLO040/FLOW//1DAY/DWR-DMS-201707/

# %%
cb=pydsm.io.read_table_as_df(filename,'/hydro/geometry/channel_bottom')
display(cb)
print('Channel Bottom for Channel Number: ',441)
print(cb[channel_number2index[441]])
# Out:
#         0           1           2       3          4          5          6    \
# 0  3.502402       2.509  -1.5088058  -4.334     -5.233  -4.291078  -8.331375
# 1     2.509  -1.5088058      -1.844  -5.247  -4.291078  -8.331375      -11.9
#
#           7           8          9    ...      511      512         513  \
# 0     -10.903  -7.5439568  -8.892461  ...  -41.006  -16.633  -3.4955595
# 1  -7.5439568   -8.892461  -8.513715  ...   -22.57  -20.937      -4.967
#
#           514      515     516         517       518       519       520
# 0       -4.41   -4.156  -4.596     -10.672  -16.3335  -11.8615     -0.31
# 1  -3.4955595  -10.189  -7.519  -11.144672   -10.672  -16.3335  -11.8615
#
# [2 rows x 521 columns]
# Channel Bottom for Channel Number:  441
# 0    -69.571
# 1    -52.325
# Name: 420, dtype: object

# %%
f5=h5py.File(filename,'r')
catable=f5['/hydro/data/channel area']

# %%
pydsm.io.read_table_attr(filename,'/hydro/data/channel area' )
# Out:
# {'CLASS': array([b'TIMESERIES'], dtype='|S10'),
#  'DIMENSION_LABELS': array([b'channel_number', b'channel_number', b'time'], dtype=object),
#  'DIMENSION_LIST': array([array([<HDF5 object reference>, <HDF5 object reference>], dtype=object),
#         array([], dtype=object), array([], dtype=object)], dtype=object),
#  'interval': array([b'30min'], dtype='|S5'),
#  'model': array([b'Hydro'], dtype='|S5'),
#  'model_version': array([b'8.2'], dtype='|S3'),
#  'start_time': array([b'1990-01-02 00:00:00'], dtype='|S19'),
#  'shape': '(1393, 521, 2)'}

# %%
table_metadata=pydsm.io.read_table_attr(filename,'/hydro/data/channel area')
display(table_metadata)
pd.to_timedelta(str(table_metadata['interval'].astype(str)[0]))
pd.to_datetime(table_metadata['start_time'].astype(str)[0])
# Out:
# {'CLASS': array([b'TIMESERIES'], dtype='|S10'),
#  'DIMENSION_LABELS': array([b'channel_number', b'channel_number', b'time'], dtype=object),
#  'DIMENSION_LIST': array([array([<HDF5 object reference>, <HDF5 object reference>], dtype=object),
#         array([], dtype=object), array([], dtype=object)], dtype=object),
#  'interval': array([b'30min'], dtype='|S5'),
#  'model': array([b'Hydro'], dtype='|S5'),
#  'model_version': array([b'8.2'], dtype='|S3'),
#  'start_time': array([b'1990-01-02 00:00:00'], dtype='|S19'),
#  'shape': '(1393, 521, 2)'}
# Timestamp('1990-01-02 00:00:00')

# %%
class TableMetaData:
    pass
tmd=TableMetaData()
tmd.table_name='/hydro/data/channel area'
tmd.interval=pd.to_timedelta('30min')
tmd.start_time=pd.to_datetime('1990-01-02 00:00:00')
tmd.dimension_labels=table_metadata['DIMENSION_LABELS'].astype('str')
from ast import literal_eval as make_tuple
tmd.shape=make_tuple(table_metadata['shape'])
print(tmd.shape)
# Out:
# (1393, 521, 2)

# %%
s=pydsm.io._convert_time_to_table_slice("01jan1980","01jan1991",tmd.interval,tmd.start_time,tmd.shape[0])
print(s)
x=catable[s,[501,502],0]
#pydsm.io.read_table_as_df(filename,"/hydro/data/channel area",s)
# Out:
# slice(0, 1393, 1)

# %%
bf=pd.DataFrame(data=np.array(x), index=pd.DatetimeIndex(data=pd.date_range(start=tmd.start_time+tmd.interval,freq=tmd.interval,periods=s.stop)))

# %%
catable
# Out:
# <HDF5 dataset "channel area": shape (1393, 521, 2), type "<f4">

# %%
bf.plot()

# %%
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/external_flow_names'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/hydro_comp_point'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/node_flow_connections'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/qext'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/reservoir_flow_connections'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/reservoir_names'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/reservoir_node_connect'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/stage_boundaries'))
display(pydsm.io.read_table_as_df(filename,'/hydro/geometry/transfer_names'))
# Out:
#                    0
# 0          calaveras
# 1           cosumnes
# 2               moke
# 3          north_bay
# 4                sac
# ..               ...
# 785         stockton
# 786    dicu_div_bbid
# 787  dicu_drain_bbid
# 788   dicu_seep_bbid
# 789              swp
#
# [790 rows x 1 columns]
#      comp_index channel distance
# 0             1       1      0.0
# 1             2       1   6500.0
# 2             3       1  13000.0
# 3             4       1  19500.0
# 4             5       2      0.0
# ...         ...     ...      ...
# 1218       1219     520   5000.0
# 1219       1220     520  10000.0
# 1220       1221     521      0.0
# 1221       1222     521   5000.0
# 1222       1223     521  10000.0
#
# [1223 rows x 3 columns]
#     connection_index int_node_no ext_node_no node_flow_index flow_index  \
# 0                  1           1           1               1         12
# 1                  2           1           1               2        269
# 2                  3           1           1               3        526
# 3                  4           3           3               1        165
# 4                  5           3           3               2        422
# ..               ...         ...         ...             ...        ...
# 781              782         410         320               1        185
# 782              783         410         320               2        442
# 783              784         410         320               3        699
# 784              785         428         446               1          2
# 785              786         429         447               1          3
#
#                             flow_name flow_type
# 0    dicu_div_1                        qext
# 1    dicu_drain_1                      qext
# 2    dicu_seep_1                       qext
# 3    dicu_div_3                        qext
# 4    dicu_drain_3                      qext
# ..                                ...       ...
# 781  dicu_div_320                      qext
# 782  dicu_drain_320                    qext
# 783  dicu_seep_320                     qext
# 784  cosumnes                          qext
# 785  moke                              qext
#
# [786 rows x 7 columns]
#                                  name                   attach_obj_name  \
# 0    calaveras                                   21
# 1    cosumnes                                   446
# 2    moke                                       447
# 3    north_bay                                  273
# 4    sac                                        330
# ..                                ...                               ...
# 785  stockton                                    15
# 786  dicu_div_bbid                     clifton_court
# 787  dicu_drain_bbid                   clifton_court
# 788  dicu_seep_bbid                    clifton_court
# 789  swp                               clifton_court
#
#     attached_obj_type attached_obj_no
# 0                   2              20
# 1                   2             428
# 2                   2             429
# 3                   2             402
# 4                   2             295
# ..                ...             ...
# 785                 2              15
# 786                 3               2
# 787                 3               2
# 788                 3               2
# 789                 3               2
#
# [790 rows x 4 columns]
#   connection_index                          res_name res_index res_flow_index  \
# 0                1  clifton_court                            2              1
# 1                2  clifton_court                            2              2
# 2                3  clifton_court                            2              3
# 3                4  clifton_court                            2              4
#
#   flow_index                         flow_name flow_type
# 0        787  dicu_div_bbid                     qext
# 1        788  dicu_drain_bbid                   qext
# 2        789  dicu_seep_bbid                    qext
# 3        790  swp                               qext
#                0
# 0         bethel
# 1  clifton_court
# 2  discovery_bay
# 3   franks_tract
# 4        liberty
# 5        mildred
#    res_node_index                          res_name res_index connect_index  \
# 0               1  bethel                                   1             1
# 1               2  clifton_court                            2             1
# 2               3  discovery_bay                            3             1
# 3               4  discovery_bay                            3             2
# 4               5  franks_tract                             4             1
# 5               6  franks_tract                             4             2
# 6               7  franks_tract                             4             3
# 7               8  franks_tract                             4             4
# 8               9  franks_tract                             4             5
# 9              10  franks_tract                             4             6
# 10             11  liberty                                  5             1
# 11             12  mildred                                  6             1
# 12             13  mildred                                  6             2
# 13             14  mildred                                  6             3
# 14             15  mildred                                  6             4
#
#    node_no ext_node_no connection_type
# 0      203         220        node
# 1       71          72        gate
# 2      183         197        node
# 3      184         198        node
# 4       98         103        node
# 5      199         216        node
# 6      202         219        node
# 7      207         224        node
# 8      208         225        node
# 9      212         232        node
# 10     288         322        node
# 11     122         127        node
# 12     124         129        node
# 13     125         130        node
# 14     131         136        node
#                                name int_node_no ext_node_no
# 0  mtz                                      412         361
#   0
# 0

# %%
pd.DataFrame(h5f.get('/hydro/geometry/channel_location'),dtype=np.str)
# Out:
#             0
# 0    upstream
# 1  downstream

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 5]

# %%
import pydsm.hydroh5

# %%
hydroh5=pydsm.hydroh5.HydroH5(filename)

# %%
flow4up=hydroh5.get_channel_flow('4','upstream')
flow8down=hydroh5.get_channel_flow('8','downstream')
ax1=flow4up.plot()
flow8down.plot(ax=ax1)

# %%
area4up=hydroh5.get_channel_area('4','upstream')
area8down=hydroh5.get_channel_area('8','downstream')
ax1=area4up.plot()
area8down.plot(ax=ax1)

# %%
vel4up=(flow4up/area4up)
vel8down=(flow8down/area8down)
ax1=vel4up.plot()
vel8down.plot(ax=ax1)

# %%
vel4up.index.freqstr
# Out:
# '30T'
